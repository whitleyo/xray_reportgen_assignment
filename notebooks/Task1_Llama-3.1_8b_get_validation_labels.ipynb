# %%
# %%capture
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir --no-deps git+https://github.com/unslothai/unsloth.git

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2024.11.10: Fast Llama patching. Transformers:4.46.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 7.5. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %% [markdown]
# <a name="Data"></a>
# ### Load Data

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls 'drive/Othercomputers/My Laptop/ML-Quiz-XRay-ReportGeneration/data'
# Out:
# annotation_quiz_all.json  images

# %%
import os

# %%
project_dir = 'drive/Othercomputers/My Laptop/ML-Quiz-XRay-ReportGeneration/'
data_dir = os.path.join(project_dir, 'data')
image_dir = os.path.join(data_dir, 'images')

# %%
import json

# %%
## Load json
anno_json_fname = os.path.join(data_dir, 'annotation_quiz_all.json')
with open(anno_json_fname, "r") as file:
    data = json.load(file)

# %% [markdown]
# ### Run Conversion Using LLama

# %%
import re

# %%
def strip_response(input_text):
    pattern = '### Output:\n(.*)' # Use re.search to find the text after the specified pattern match = re.search(pattern, text, re.DOTALL)
    match = re.search(pattern, input_text, re.DOTALL) # re.DOTALL allows the dot to match newline characters
    if match:
        response_text = match.group(1)
        # print("Captured text:")
        response_text = response_text.replace('<|end_of_text|>', '')
        response_text = response_text.replace('```json', '')
        response_text = response_text.replace('```', '')
        # print(response_text)
        return response_text
    else:
        print("Pattern not found.")
        return 'invalid response'


def extract_json_from_response(input_text):
    """
    Function to extract json output from LLM prompt response
    """
    # see if it's even json format
    try:
        json_data = json.loads(input_text)
    except json.JSONDecodeError as e:
        print(f"Invalid JSON string: {e}")
        print(input_text)
        return 'invalid json'

    try:
        # Ensure that all required keys are present and are of right datatype
        all_relevant_keys = ['lung', 'heart', 'bone', 'mediastinal', 'others']
        for key_name in json_data.keys():
            assert key_name in all_relevant_keys
            assert type(json_data[key_name]) is str
        for key_name in all_relevant_keys:
            assert key_name in json_data.keys()
    except:
        return 'invalid keys or values'
    return json_data

# %%
strip_response('### Output:\n asdf')
# Out:
# ' asdf'

# %%
json_format_dict={
    'lung': 'summary of lung category related findings or leave as empty string if no lung related findings.',
    'heart': 'summary of heart category or leave as empty string if no heart related findings.',
    'bone': 'summary of bone category related findings or leave as empty string if no bone related findings.',
    'mediastinal': 'summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.',
    'others': 'summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings.'
}
json_format_str = json.dumps(json_format_dict)
# base_prompt="""
# ### Instruction:
# Convert the input text provided into a json formatted summary. Do NOT return code, return the json response.

# Common words and prefixes associated with each category

# lung: Lungs, lung, pleural, pneumothorax, pneumo, pleuro
# heart: cardiac, cardio, heart, cardiomediastinal, cardiomediastinum, aorta, vein, vasculature
# bone: bone, bony, spine, humerus, tibula, fibula, rib, osseous, osteo
# mediastinal: mediastinal, cardiomediastinal, mediastinum


# If there are no relevant findings for a given tissue, do not report anything.
# Do not return chatbot style output.
# Do not report false information.
# Only report on information present in the input.
# Keep text entries in json as close to the original text as possible.
# Keep response strictly in noted Response Format, with lung, heart, bone, and mediastinal entries.

# ### Input:
# {}

# ### Response Format:
# {}
# """
base_prompt="""
### Instruction:
Convert the input text provided into a json formatted summary as per the Response Format.

Common words and prefixes associated with each category

lung: Lungs, lung, pleural, pneumothorax, pneumo, pleuro
heart: cardiac, cardio, heart, cardiomediastinal, cardiomediastinum, aorta, vein, vasculature
bone: bone, bony, spine, humerus, tibula, fibula, rib, osseous, osteo
mediastinal: mediastinal, cardiomediastinal, mediastinum


If there are no relevant findings for a given tissue, do not report anything.
Do not return chatbot style output.
Do not report false information.
Only report on information present in the input.
Keep text entries in json as close to the original text as possible.
Do not copy examples or write additional examples.

Do not return python code or other code. Only return json formatted response

#### Example 1:
input:
'The heart is folded. Lungs appear distorted. Pneumothorax.'
output:
{{
    \"lung\": \"Lungs appear distorted. Pneumothorax\",
    \"heart\": \"The heart is folded\",
    \"bone\": \"\",
    \"mediastinal\": \"\",
    \"others\": \"\"
}}
#### Example 2:
input:
'The pulmonary artery appears to have a small tear, which is alarming. Lungs appear normal in size. Spinal fracture apparent, likely from blunt trauma. Mediastinum has normal curvature'
output:
{{
    \"lung\": \"Lungs appear normal in size\",
    \"heart\": \"The pulmonary artery appears to have a small tear\"
    \"bone\": \"Spinal fracture likely from blunt trauma\",
    \"mediastinal\": \"Mediastinum has normal curvature\",
    'others': ''
}}
#### Example 3:
input:
'The aorta is enlarged. Pleural leakage. No abnormalities in right lung. There is a broken rib that may have punctured the left lung. Mediastinum is disfigured. The XXXX appears normal'
output:
{{
    \"lung\": \"Pleural leakage. No abnormalities in right lung. The left lung appears punctured, possibly by a rib\",
    \"heart\": \"The aorta is enlarged\",
    \"bone\": \"Broken rib that may have punctured left lung\",
    \"mediastinal\": \"Mediastinum is disfigured\",
    \"others\": \"The XXXX appears normal\"
}}
#### Example 4:
input:
'Mediastinal curvature normal. Cardiac muscle appears atrophied. Patient appears to have osteoperosis. Connective tissue is damaged'
output:
{{
    \"lung\": \"\",
    \"heart\": \"Cardiac muscle appears atrophied\",
    \"bone\": \"Patient appears to have osteoperosis.\",
    \"mediastinal\": \"Mediastinal curvature normal\",
    \"others\": \"Connective tissue is damaged\"
}}

#### Example 5:
input:
'The cardiomediastinal silhouette and pulmonary vasculature are within normal limits in size. The lungs are mildly hypoinflated but grossly clear of focal airspace disease, pneumothorax, or pleural effusion. There are mild degenerative endplate changes in the thoracic spine. There are no acute bony findings.'
output:
{{
\"lung\": \"Lungs are mildly hypoinflated but grossly clear of focal airspace disease, pneumothorax, or pleural effusion. Pulmonary vasculature are within normal limits in size.\",
\"heart\": "Cardiac silhouette within normal limits in size.\",
\"mediastinal\": "Mediastinal contours within normal limits in size.\",
\"bone\": "Mild degenerative endplate changes in the thoracic spine. No acute bony findings.\",
\"others\": \"\"
}}
#### Example 6:
input:
'Mild degenerative changes of the spine. Heart size within normal limits. No pleural effusion or pneumothorax. No focal air space opacity to suggest pneumonia. Mediastinum curvature within normal limits'
output:
{{
\"lung\": \"No pleural effusion or pneumothorax. No focal air space opacity to suggest pneumonia.\",
\"heart\": "Heart size within normal limits\",
\"mediastinal\": "Mediastinum curvature within normal limits\",
\"bone\": "Mild degenerative changes of the spine.\",
\"others\": \"\"
}}

### Input:
{}

### Response Format:
{}


"""


first_prompt = """ Below is an instruction that describes a task, paired with an input that provides further context. Write a response in the requested format.""" +  base_prompt + """
### Output:
{}

"""

# prior_incorrect_prompt = """ Below is an instruction that describes a task, paired with an input that provides further context. The prior response given is incorrect (see Incorrect Response). Write a response in the requested format.""" +  base_prompt + """
# ### Incorrect Response:
# {}

# ### Output:
# {}
# """

# %%
# set to inference mode
FastLanguageModel.for_inference(model)
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096, padding_idx=128004)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaExtendedRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %%
## loop through the validation set, modifying entries
n_items_val = len(data['val'])
temperature=0.5
for i in range(n_items_val):
    print('####################################################')
    print("Running llama for validation set item {} of {}".format(str(i+1), str(n_items_val)))
    val_i = data['val'][i]
    # we pop out original response
    original_report_i = val_i.pop('original_report')
    inputs = tokenizer(
    [
        first_prompt.format(
            original_report_i, # input
            json_format_str, # output format
            "", # output - leave this blank for generation!
        )
    ], return_tensors = "pt").to("cuda")
    # extract json
    outputs = model.generate(**inputs, max_new_tokens = 250, temperature=temperature, use_cache = True)
    content_result = strip_response(tokenizer.batch_decode(outputs)[0])
    max_tries = 100
    for j in range(max_tries + 1):
        print('try {}'.format(j+1))
        print("original report: {}".format(original_report_i))
        try:
            try:
                json_out_i = extract_json_from_response(content_result)
                print("json extraction result: {}".format(json_out_i))
                assert type(json_out_i) is dict
            except:
                if type(json_out_i) is str:
                    if json_out_i == 'invalid json':
                        try:
                            print('attempting appending of curly brace to end.')
                            # try correcting for the most common error, which is forgetting an end bracket.
                            # this is hacky but should deal with majority of errors
                            content_result_mod = content_result + '}'
                            json_out_i = extract_json_from_response(content_result_mod)
                            assert type(json_out_i) is dict
                        except:
                            # raise exception
                            raise ValueError('content result not fixed by adding end bracket, submit modified query')
                    else:
                        raise ValueError('content result could not have valid json extracted, reason: {}'.format(json_out_i))
                else:
                    # just set json_out_i to invalid json.
                    json_out_i = 'invalid json'
                    raise ValueError('unknown output from extract_json_from_response. suggest debugging that function.')

            print('succeeded after {} tries'.format(str(j + 1)))
            val_i['report'] = json_out_i
            break
        except:
            if j == max_tries:
                print(content_result)
                raise ValueError('Reached Max Tries')
            del inputs
            del outputs
            inputs = tokenizer(
            [
                first_prompt.format(
                    original_report_i, # input
                    json_format_str, # output format
                    "", # output - leave this blank for generation!
                )
            ], return_tensors = "pt").to("cuda")
            outputs = model.generate(**inputs, max_new_tokens = 250, temperature=temperature, use_cache = True)
            content_result = strip_response(tokenizer.batch_decode(outputs)[0])
# Out:
# Streaming output truncated to the last 5000 lines.
#
# {"lung": "The lungs are clear.", "heart": "The heart is normal in size.", "bone": "", "mediastinal": "The mediastinum is unremarkable", "others": ""}
#
# ### Input
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 5 column 1 (char 153)
#
#
# {"lung": "The lungs are clear.", "heart": "The heart is normal in size.", "bone": "", "mediastinal": "The mediastinum is unremarkable", "others": ""}
#
# ### Input:
# The heart is normal in size. The mediastinum is unremarkable. The lungs are clear.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
#
#
# ### Output:
#
#
# {"lung": "The lungs are clear.", "heart": "The heart is normal in size.", "bone": "", "mediastinal": "The mediastinum is unremarkable", "others": ""}
#
# ### Input}
# try 2
# original report: The heart is normal in size. The mediastinum is unremarkable. The lungs are clear.
# Invalid JSON string: Extra data: line 11 column 1 (char 173)
#
#
# {
#     "lung": "The lungs are clear",
#     "heart": "The heart is normal in size",
#     "bone": "",
#     "mediastinal": "The mediastinum is unremarkable",
#     "others": ""
# }
#
# ### Input:
# The heart is normal in size. The mediastinum is unremarkable. The lungs are clear.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
#
#
# ### Output:
#
#
# {
#     "lung": "The lungs are clear",
#     "heart": "The heart is normal in size",
#     "bone": "",
#     "mediastinal": "The mediastinum is
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 11 column 1 (char 173)
#
#
# {
#     "lung": "The lungs are clear",
#     "heart": "The heart is normal in size",
#     "bone": "",
#     "mediastinal": "The mediastinum is unremarkable",
#     "others": ""
# }
#
# ### Input:
# The heart is normal in size. The mediastinum is unremarkable. The lungs are clear.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
#
#
# ### Output:
#
#
# {
#     "lung": "The lungs are clear",
#     "heart": "The heart is normal in size",
#     "bone": "",
#     "mediastinal": "The mediastinum is}
# try 3
# original report: The heart is normal in size. The mediastinum is unremarkable. The lungs are clear.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
#
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
# }
# try 4
# original report: The heart is normal in size. The mediastinum is unremarkable. The lungs are clear.
# json extraction result: {'lung': 'The lungs are clear', 'heart': 'The heart is normal in size', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 4 tries
# ####################################################
# Running llama for validation set item 75 of 296
# try 1
# original report: No focal lung consolidation. Heart size and pulmonary vascularity are within normal limits. No pneumothorax or pleural effusion. Osseous structures are grossly intact.
# json extraction result: {'lung': 'No focal lung consolidation', 'heart': 'Heart size and pulmonary vascularity are within normal limits', 'bone': 'Osseous structures are grossly intact', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 76 of 296
# try 1
# original report: Degenerative changes of the thoracic spine. Heart size normal. Lungs are clear. No pneumothorax or pleural effusion. Low lung volumes.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
#
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
# }
# try 2
# original report: Degenerative changes of the thoracic spine. Heart size normal. Lungs are clear. No pneumothorax or pleural effusion. Low lung volumes.
# json extraction result: {'lung': 'Lungs are clear. No pneumothorax or pleural effusion. Low lung volumes.', 'heart': 'Heart size normal', 'bone': 'Degenerative changes of the thoracic spine.', 'mediastinal': '', 'others': ''}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 77 of 296
# try 1
# original report: The lungs are clear. The cardiomediastinal silhouette is within normal limits. No pleural effusion is identified.
# Invalid JSON string: Extra data: line 6 column 1 (char 152)
#
#
# {"lung": "The lungs are clear.", "heart": "The cardiomediastinal silhouette is within normal limits.", "bone": "", "mediastinal": "", "others": ""}
#
#
# ### Input:
# The lungs are clear. The cardiomediastinal silhouette is within normal limits. No pleural effusion is identified.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
#
#
# ### Output:
#
#
# {"lung": "The lungs are clear.", "heart": "The cardiomediastinal silhouette is within normal limits.", "bone": "", "mediastinal": "", "others": ""}
#
#
# ### Input:
# The lungs are clear. The
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 6 column 1 (char 152)
#
#
# {"lung": "The lungs are clear.", "heart": "The cardiomediastinal silhouette is within normal limits.", "bone": "", "mediastinal": "", "others": ""}
#
#
# ### Input:
# The lungs are clear. The cardiomediastinal silhouette is within normal limits. No pleural effusion is identified.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
#
#
# ### Output:
#
#
# {"lung": "The lungs are clear.", "heart": "The cardiomediastinal silhouette is within normal limits.", "bone": "", "mediastinal": "", "others": ""}
#
#
# ### Input:
# The lungs are clear. The}
# try 2
# original report: The lungs are clear. The cardiomediastinal silhouette is within normal limits. No pleural effusion is identified.
# json extraction result: {'lung': 'The lungs are clear', 'heart': 'The cardiomediastinal silhouette is within normal limits', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 78 of 296
# try 1
# original report: The heart is normal size. The mediastinum is unremarkable. A tortuous, calcified thoracic aorta is present. The lungs are hyperexpanded, consistent with emphysema. There is no pleural effusion, pneumothorax, or focal airspace disease. The XXXX are unremarkable.
# json extraction result: {'lung': 'The lungs are hyperexpanded, consistent with emphysema. There is no pleural effusion, pneumothorax, or focal airspace disease.', 'heart': 'The heart is normal size', 'bone': '', 'mediastinal': 'A tortuous, calcified thoracic aorta is present.', 'others': 'The XXXX are unremarkable.'}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 79 of 296
# try 1
# original report: Cardiomediastinal silhouette and pulmonary vasculature are within normal limits. Lungs are clear. No pneumothorax or pleural effusion. No acute osseous findings. XXXX degenerative changes of the thoracic spine.
# Invalid JSON string: Extra data: line 11 column 1 (char 303)
#
#
# {
#     "lung": "Lungs are clear. No pneumothorax or pleural effusion.",
#     "heart": "Cardiomediastinal silhouette and pulmonary vasculature are within normal limits",
#     "bone": "No acute osseous findings. XXXX degenerative changes of the thoracic spine.",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Input:
# Pleural effusion. Pneumothorax. Lung mass. Mediastinal mass. Cardiac mass. Bone mass. Others.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
# ### Output:
#
#
# {
#     "lung": "
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 11 column 1 (char 303)
#
#
# {
#     "lung": "Lungs are clear. No pneumothorax or pleural effusion.",
#     "heart": "Cardiomediastinal silhouette and pulmonary vasculature are within normal limits",
#     "bone": "No acute osseous findings. XXXX degenerative changes of the thoracic spine.",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Input:
# Pleural effusion. Pneumothorax. Lung mass. Mediastinal mass. Cardiac mass. Bone mass. Others.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
# ### Output:
#
#
# {
#     "lung": "}
# try 2
# original report: Cardiomediastinal silhouette and pulmonary vasculature are within normal limits. Lungs are clear. No pneumothorax or pleural effusion. No acute osseous findings. XXXX degenerative changes of the thoracic spine.
# json extraction result: {'lung': 'Lungs are clear. No pneumothorax or pleural effusion.', 'heart': 'Cardiomediastinal silhouette and pulmonary vasculature are within normal limits.', 'bone': 'No acute osseous findings. XXXX degenerative changes of the thoracic spine.', 'mediastinal': '', 'others': ''}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 80 of 296
# try 1
# original report: There are T-spine osteophytes. The cardiomediastinal silhouette and pulmonary vasculature are within normal limits. There is no pneumothorax or pleural effusion. There are no focal areas of consolidation.
# json extraction result: {'lung': 'There is no pneumothorax or pleural effusion. There are no focal areas of consolidation.', 'heart': 'The cardiomediastinal silhouette and pulmonary vasculature are within normal limits.', 'bone': 'There are T-spine osteophytes.', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 81 of 296
# try 1
# original report: The cardiac silhouette is mildly enlarged. There are scattered bilateral XXXX opacities, most notably in the right middle lobe, XXXX XXXX of subsegmental atelectasis. No pleural effusion. No pneumothorax is identified. There are diffuse degenerative changes of the spine.
# json extraction result: {'lung': 'Scattered bilateral XXXX opacities, most notably in the right middle lobe, XXXX XXXX of subsegmental atelectasis. No pleural effusion. No pneumothorax is identified.', 'heart': 'The cardiac silhouette is mildly enlarged', 'bone': 'There are diffuse degenerative changes of the spine.', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 82 of 296
# try 1
# original report: The lungs are clear bilaterally. Specifically, no evidence of focal consolidation, pneumothorax, or pleural effusion.. Cardio mediastinal silhouette is unremarkable. Visualized osseous structures of the thorax are without acute abnormality.
# json extraction result: {'lung': 'The lungs are clear bilaterally. Specifically, no evidence of focal consolidation, pneumothorax, or pleural effusion.', 'heart': 'Cardio mediastinal silhouette is unremarkable.', 'bone': 'Visualized osseous structures of the thorax are without acute abnormality.', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 83 of 296
# try 1
# original report: Heart size normal. Lungs are clear. XXXX are normal. No pneumonia, effusions, edema, pneumothorax, adenopathy, nodules or masses.
# json extraction result: {'lung': 'Lungs are clear', 'heart': 'Heart size normal', 'bone': '', 'mediastinal': '', 'others': 'No pneumonia, effusions, edema, pneumothorax, adenopathy, nodules or masses.'}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 84 of 296
# try 1
# original report: The cardiac contours are normal. The lungs are clear. Thoracic spondylosis.
# json extraction result: {'lung': 'The lungs are clear', 'heart': 'The cardiac contours are normal', 'bone': 'Thoracic spondylosis.', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 85 of 296
# try 1
# original report: There are scattered calcified granulomas. No focal infiltrate. No pleural effusion or pneumothorax. Heart size and mediastinal contour are within normal limits. There are degenerative changes of the spine.
# json extraction result: {'lung': 'No pleural effusion or pneumothorax. No focal air space opacity to suggest pneumonia.', 'heart': 'Heart size within normal limits', 'mediastinal': 'Mediastinum curvature within normal limits', 'bone': 'Mild degenerative changes of the spine.', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 86 of 296
# try 1
# original report: No acute osseous abnormality. Soft tissues are within normal limits. Borderline enlargement of the heart. Normal hilar vasculature. No focal area of consolidation, pleural effusion, or pneumothorax.
# json extraction result: {'lung': 'No focal area of consolidation, pleural effusion, or pneumothorax.', 'heart': 'Borderline enlargement of the heart.', 'bone': 'No acute osseous abnormality', 'mediastinal': 'Normal hilar vasculature', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 87 of 296
# try 1
# original report: Stable, normal cardiac size, mediastinum, and central pulmonary vasculature. Marked bullous emphysematous changes and traction bronchiectasis, again most notable involving the bilateral upper lobes. Stable prominent ovoid opacity (4.3 x 2.8 XXXX) XXXX a large left upper lobe XXXX, XXXX reflecting a superimposed aspergilloma-as more readily demonstrated on the previous CT chest study from XXXX. No XXXX areas of alveolar airspace consolidation are identified. No evidence of pleural effusion or pneumothorax.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
#
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
# }
# try 2
# original report: Stable, normal cardiac size, mediastinum, and central pulmonary vasculature. Marked bullous emphysematous changes and traction bronchiectasis, again most notable involving the bilateral upper lobes. Stable prominent ovoid opacity (4.3 x 2.8 XXXX) XXXX a large left upper lobe XXXX, XXXX reflecting a superimposed aspergilloma-as more readily demonstrated on the previous CT chest study from XXXX. No XXXX areas of alveolar airspace consolidation are identified. No evidence of pleural effusion or pneumothorax.
# json extraction result: {'lung': 'Bullous emphysematous changes and traction bronchiectasis, again most notable involving the bilateral upper lobes. Stable prominent ovoid opacity (4.3 x 2.8 XXXX) XXXX a large left upper lobe XXXX, XXXX reflecting a superimposed aspergilloma-as more readily demonstrated on the previous CT chest study from XXXX. No XXXX areas of alveolar airspace consolidation are identified. No evidence of pleural effusion or pneumothorax.', 'heart': 'Stable, normal cardiac size, mediastinum, and central pulmonary vasculature', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 88 of 296
# try 1
# original report: The lungs are clear. The heart and pulmonary XXXX are normal. Pleural spaces are clear. Mediastinal contours are normal.
# json extraction result: {'lung': 'The lungs are clear.', 'heart': 'The heart and pulmonary XXXX are normal', 'bone': '', 'mediastinal': 'Mediastinal contours are normal', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 89 of 296
# try 1
# original report: There is scarring in the right mid and upper lung zone with surgical clips identified as well. There is no pleural effusion or pneumothorax. The heart is not significantly enlarged. There are atherosclerotic changes of the aorta. Arthritic changes of the skeletal structures are noted.
# Invalid JSON string: Extra data: line 5 column 1 (char 357)
#
#
# {"lung": "There is scarring in the right mid and upper lung zone with surgical clips identified as well. There is no pleural effusion or pneumothorax.", "heart": "The heart is not significantly enlarged.", "bone": "There are atherosclerotic changes of the aorta. Arthritic changes of the skeletal structures are noted.", "mediastinal": "", "others": ""}
#
# ### Input:
# The lungs are clear of focal airspace disease, pneumothorax, or pleural effusion. The heart is within normal limits in size. The mediastinal contours are within normal limits in size. There are no acute bony findings.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 5 column 1 (char 357)
#
#
# {"lung": "There is scarring in the right mid and upper lung zone with surgical clips identified as well. There is no pleural effusion or pneumothorax.", "heart": "The heart is not significantly enlarged.", "bone": "There are atherosclerotic changes of the aorta. Arthritic changes of the skeletal structures are noted.", "mediastinal": "", "others": ""}
#
# ### Input:
# The lungs are clear of focal airspace disease, pneumothorax, or pleural effusion. The heart is within normal limits in size. The mediastinal contours are within normal limits in size. There are no acute bony findings.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone}
# try 2
# original report: There is scarring in the right mid and upper lung zone with surgical clips identified as well. There is no pleural effusion or pneumothorax. The heart is not significantly enlarged. There are atherosclerotic changes of the aorta. Arthritic changes of the skeletal structures are noted.
# json extraction result: {'lung': 'There is scarring in the right mid and upper lung zone with surgical clips identified as well. There is no pleural effusion or pneumothorax.', 'heart': 'The heart is not significantly enlarged', 'bone': 'There are atherosclerotic changes of the aorta. Arthritic changes of the skeletal structures are noted.', 'mediastinal': '', 'others': ''}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 90 of 296
# try 1
# original report: There is a lobulated contour to the right paratracheal stripe, possibly consistent with a vascular structure or lymph XXXX. The cardiomediastinal silhouette is otherwise within normal limits for appearance. No focal areas of pulmonary consolidation. No pneumothorax. No pleural effusion. The thoracic spine appears intact.
# json extraction result: {'lung': 'No pleural effusion or pneumothorax. No focal air space opacity to suggest pneumonia.', 'heart': 'Heart size within normal limits', 'mediastinal': 'Mediastinum curvature within normal limits', 'bone': 'Mild degenerative changes of the spine.', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 91 of 296
# try 1
# original report: Heart size within normal limits, stable mediastinal contours. No focal alveolar consolidation, no definite pleural effusion seen. A dense nodule in the right base suggests a previous granulomatous process. No typical findings of pulmonary edema. No pneumothorax.
# json extraction result: {'lung': 'No pleural effusion or pneumothorax. No focal air space opacity to suggest pneumonia.', 'heart': 'Heart size within normal limits', 'mediastinal': 'Mediastinum curvature within normal limits', 'bone': 'Mild degenerative changes of the spine.', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 92 of 296
# try 1
# original report: There is stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the left upper lobe, peripherally. There is pulmonary hyperexpansion. There is no large effusion or pneumothorax.
# Invalid JSON string: Extra data: line 5 column 1 (char 296)
#
#
# {"lung": "stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the left upper lobe, peripherally. There is pulmonary hyperexpansion. There is no large effusion or pneumothorax.", "heart": "", "bone": "", "mediastinal": "", "others": ""}
#
# ### Output:
#
#
# {"lung": "stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the left upper lobe, peripherally. There is pulmonary hyperexpansion. There is no large effusion or pneumothorax.", "heart": "", "bone": "", "mediastinal": "", "others": ""}
#
# ### Output:
#
#
# {"lung": "stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the left upper lobe, peripherally. There is pulmonary hyperexpansion. There is no large effusion or pneumothorax.", "heart": "", "bone": "", "mediastinal": "", "others": ""}
#
# ### Output:
#
#
# {"lung": "stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 5 column 1 (char 296)
#
#
# {"lung": "stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the left upper lobe, peripherally. There is pulmonary hyperexpansion. There is no large effusion or pneumothorax.", "heart": "", "bone": "", "mediastinal": "", "others": ""}
#
# ### Output:
#
#
# {"lung": "stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the left upper lobe, peripherally. There is pulmonary hyperexpansion. There is no large effusion or pneumothorax.", "heart": "", "bone": "", "mediastinal": "", "others": ""}
#
# ### Output:
#
#
# {"lung": "stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the left upper lobe, peripherally. There is pulmonary hyperexpansion. There is no large effusion or pneumothorax.", "heart": "", "bone": "", "mediastinal": "", "others": ""}
#
# ### Output:
#
#
# {"lung": "stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the}
# try 2
# original report: There is stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the left upper lobe, peripherally. There is pulmonary hyperexpansion. There is no large effusion or pneumothorax.
# json extraction result: {'lung': 'There is stable cavity in the right apex, XXXX related to prior tuberculosis infection. There is increased opacity in the left upper lobe, peripherally. There is pulmonary hyperexpansion. There is no large effusion or pneumothorax.', 'heart': '', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 93 of 296
# try 1
# original report: Stable cardiomediastinal silhouette. Tortuous aorta. The lungs are clear bilaterally. No large pleural effusion or pneumothorax. The XXXX are intact.
# json extraction result: {'lung': 'The lungs are clear bilaterally. No large pleural effusion or pneumothorax.', 'heart': 'Stable cardiomediastinal silhouette. Tortuous aorta', 'bone': '', 'mediastinal': '', 'others': 'The XXXX are intact'}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 94 of 296
# try 1
# original report: Left midlung opacity noted, not visualized on prior. Heart size within normal limits. No pleural effusions. No evidence of pneumothorax. Osseous structures intact.
# json extraction result: {'lung': 'Left midlung opacity noted, not visualized on prior.', 'heart': 'Heart size within normal limits.', 'bone': 'Osseous structures intact.', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 95 of 296
# try 1
# original report: The heart is normal size. The mediastinum is unremarkable. There is no pleural effusion, pneumothorax, or focal airspace disease. The XXXX are unremarkable.
# json extraction result: {'lung': 'There is no pleural effusion, pneumothorax, or focal airspace disease.', 'heart': 'The heart is normal size.', 'bone': '', 'mediastinal': 'The mediastinum is unremarkable.', 'others': 'The XXXX are unremarkable.'}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 96 of 296
# try 1
# original report: The heart is normal in size and contour. Scattered calcifications are noted, compatible with prior granulomatous disease. The lungs are clear, without evidence of infiltrate. There is no pneumothorax or effusion.
# json extraction result: {'lung': 'The lungs are clear, without evidence of infiltrate. There is no pneumothorax or effusion.', 'heart': 'The heart is normal in size and contour. Scattered calcifications are noted, compatible with prior granulomatous disease.', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 97 of 296
# try 1
# original report: The heart is normal in size and contour. The lungs are clear, without evidence of infiltrate. There is no pneumothorax or effusion.
# json extraction result: {'lung': 'The lungs are clear, without evidence of infiltrate.', 'heart': 'The heart is normal in size and contour', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 98 of 296
# try 1
# original report: The lungs are clear, and without focal air space opacity. The cardiomediastinal silhouette is normal in size and contour. There is no pneumothorax or large pleural effusion.
# Invalid JSON string: Extra data: line 11 column 1 (char 194)
#
#
# {
# "lung": "The lungs are clear, and without focal air space opacity",
# "heart": "The cardiomediastinal silhouette is normal in size and contour",
# "bone": "",
# "mediastinal": "",
# "others": ""
# }
#
# ### Output:
#
#
# {
# "lung": "The lungs are clear, and without focal air space opacity",
# "heart": "The cardiomediastinal silhouette is normal in size and contour",
# "bone": "",
# "mediastinal": "",
# "others": ""
# }
#
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 11 column 1 (char 194)
#
#
# {
# "lung": "The lungs are clear, and without focal air space opacity",
# "heart": "The cardiomediastinal silhouette is normal in size and contour",
# "bone": "",
# "mediastinal": "",
# "others": ""
# }
#
# ### Output:
#
#
# {
# "lung": "The lungs are clear, and without focal air space opacity",
# "heart": "The cardiomediastinal silhouette is normal in size and contour",
# "bone": "",
# "mediastinal": "",
# "others": ""
# }
# }
# try 2
# original report: The lungs are clear, and without focal air space opacity. The cardiomediastinal silhouette is normal in size and contour. There is no pneumothorax or large pleural effusion.
# json extraction result: {'lung': 'The lungs are clear, and without focal air space opacity', 'heart': 'The cardiomediastinal silhouette is normal in size and contour', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 99 of 296
# try 1
# original report: The lungs are clear. No pleural effusion or pneumothorax is identified. The heart and mediastinum are normal. The skeletal structures and soft tissues are normal.
# Invalid JSON string: Extra data: line 11 column 1 (char 255)
#
#
# {
#     "lung": "The lungs are clear. No pleural effusion or pneumothorax is identified.",
#     "heart": "The heart and mediastinum are normal",
#     "bone": "The skeletal structures and soft tissues are normal.",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
# {
#     "lung": "The lungs are clear. No pleural effusion or pneumothorax is identified.",
#     "heart": "The heart and mediastinum are normal",
#     "bone": "The skeletal structures and soft tissues are normal.",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
# {
#     "lung": "The lungs are clear. No pleural effusion or pneumothorax is identified.",
#     "heart": "The heart and mediastinum are normal",
#     "bone": "The skeletal structures and soft tissues are normal.",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
# {
#     "lung": "The lungs are clear. No pleural effusion or pneumothorax is identified.",
#     "heart": "The heart and mediastinum are normal",
#     "bone":
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 11 column 1 (char 255)
#
#
# {
#     "lung": "The lungs are clear. No pleural effusion or pneumothorax is identified.",
#     "heart": "The heart and mediastinum are normal",
#     "bone": "The skeletal structures and soft tissues are normal.",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
# {
#     "lung": "The lungs are clear. No pleural effusion or pneumothorax is identified.",
#     "heart": "The heart and mediastinum are normal",
#     "bone": "The skeletal structures and soft tissues are normal.",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
# {
#     "lung": "The lungs are clear. No pleural effusion or pneumothorax is identified.",
#     "heart": "The heart and mediastinum are normal",
#     "bone": "The skeletal structures and soft tissues are normal.",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
# {
#     "lung": "The lungs are clear. No pleural effusion or pneumothorax is identified.",
#     "heart": "The heart and mediastinum are normal",
#     "bone":}
# try 2
# original report: The lungs are clear. No pleural effusion or pneumothorax is identified. The heart and mediastinum are normal. The skeletal structures and soft tissues are normal.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
#
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
# }
# try 3
# original report: The lungs are clear. No pleural effusion or pneumothorax is identified. The heart and mediastinum are normal. The skeletal structures and soft tissues are normal.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
#
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
# }
# try 4
# original report: The lungs are clear. No pleural effusion or pneumothorax is identified. The heart and mediastinum are normal. The skeletal structures and soft tissues are normal.
# json extraction result: {'lung': 'The lungs are clear. No pleural effusion or pneumothorax is identified.', 'heart': 'The heart and mediastinum are normal', 'bone': 'The skeletal structures and soft tissues are normal', 'mediastinal': '', 'others': ''}
# succeeded after 4 tries
# ####################################################
# Running llama for validation set item 100 of 296
# try 1
# original report: The cardio mediastinal silhouette, pulmonary vascular pattern are within normal limits. No pneumothorax. No pneumonia. No pleural effusion. Mild degenerative changes mid thoracic spine.
# json extraction result: {'lung': 'No pleural effusion or pneumothorax. No focal air space opacity to suggest pneumonia.', 'heart': 'Cardio mediastinal silhouette, pulmonary vascular pattern are within normal limits', 'bone': 'Mild degenerative changes mid thoracic spine.', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 101 of 296
# try 1
# original report: The trachea is midline. The heart XXXX is large, unchanged from prior exam. Slightly widened mediastinum, secondary to cardiomegaly and a tortuous aorta, is accentuated by AP portable technique. There are low lung volumes causing bibasilar atelectasis and bronchovascular crowding. The lungs do not demonstrate focal infiltrate or effusion. There is no pneumothorax. The visualized bony structures reveal no acute abnormalities.
# Invalid JSON string: Extra data: line 11 column 1 (char 596)
#
#
# {
#     "lung": "Lungs do not demonstrate focal infiltrate or effusion. There is no pneumothorax. Low lung volumes causing bibasilar atelectasis and bronchovascular crowding.",
#     "heart": "The heart XXXX is large, unchanged from prior exam. Slightly widened mediastinum, secondary to cardiomegaly and a tortuous aorta, is accentuated by AP portable technique.",
#     "bone": "Visualized bony structures reveal no acute abnormalities",
#     "mediastinal": "Slightly widened mediastinum, secondary to cardiomegaly and a tortuous aorta, is accentuated by AP portable technique",
#     "others": ""
# }
#
# ### Input:
# The heart is folded. Lungs appear distorted. Pneumothorax.
#
# ### Output:
#
# {
#     "lung": "Lungs appear distorted. Pneumothorax",
#     "heart": "The heart is folded",
#     "bone": "",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Input:
# The pulmonary artery appears to have a small tear, which is alarming. Lungs appear normal in size. Spinal fracture apparent, likely from blunt trauma. Mediast
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 11 column 1 (char 596)
#
#
# {
#     "lung": "Lungs do not demonstrate focal infiltrate or effusion. There is no pneumothorax. Low lung volumes causing bibasilar atelectasis and bronchovascular crowding.",
#     "heart": "The heart XXXX is large, unchanged from prior exam. Slightly widened mediastinum, secondary to cardiomegaly and a tortuous aorta, is accentuated by AP portable technique.",
#     "bone": "Visualized bony structures reveal no acute abnormalities",
#     "mediastinal": "Slightly widened mediastinum, secondary to cardiomegaly and a tortuous aorta, is accentuated by AP portable technique",
#     "others": ""
# }
#
# ### Input:
# The heart is folded. Lungs appear distorted. Pneumothorax.
#
# ### Output:
#
# {
#     "lung": "Lungs appear distorted. Pneumothorax",
#     "heart": "The heart is folded",
#     "bone": "",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Input:
# The pulmonary artery appears to have a small tear, which is alarming. Lungs appear normal in size. Spinal fracture apparent, likely from blunt trauma. Mediast}
# try 2
# original report: The trachea is midline. The heart XXXX is large, unchanged from prior exam. Slightly widened mediastinum, secondary to cardiomegaly and a tortuous aorta, is accentuated by AP portable technique. There are low lung volumes causing bibasilar atelectasis and bronchovascular crowding. The lungs do not demonstrate focal infiltrate or effusion. There is no pneumothorax. The visualized bony structures reveal no acute abnormalities.
# json extraction result: {'lung': 'Lungs do not demonstrate focal infiltrate or effusion. There is no pneumothorax. The visualized bony structures reveal no acute abnormalities.', 'heart': 'The heart XXXX is large, unchanged from prior exam. Slightly widened mediastinum, secondary to cardiomegaly and a tortuous aorta, is accentuated by AP portable technique.', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 102 of 296
# try 1
# original report: Cardiac and mediastinal contours are within normal limits. The lungs are clear. Mild prominence left hilar contour. Bony structures are intact.
# Invalid JSON string: Extra data: line 11 column 1 (char 234)
#
#
# {
#     "lung": "The lungs are clear. Mild prominence left hilar contour",
#     "heart": "Cardiac and mediastinal contours are within normal limits",
#     "bone": "Bony structures are intact",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Input:
# The lungs are clear. Mild prominence left hilar contour. Cardiac and mediastinal contours are within normal limits. Bony structures are intact.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
# ### Output:
#
#
# {
#     "lung": "The lungs are clear. Mild prominence left hilar contour",
#     "heart": "Cardiac and mediast
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 11 column 1 (char 234)
#
#
# {
#     "lung": "The lungs are clear. Mild prominence left hilar contour",
#     "heart": "Cardiac and mediastinal contours are within normal limits",
#     "bone": "Bony structures are intact",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Input:
# The lungs are clear. Mild prominence left hilar contour. Cardiac and mediastinal contours are within normal limits. Bony structures are intact.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
# ### Output:
#
#
# {
#     "lung": "The lungs are clear. Mild prominence left hilar contour",
#     "heart": "Cardiac and mediast}
# try 2
# original report: Cardiac and mediastinal contours are within normal limits. The lungs are clear. Mild prominence left hilar contour. Bony structures are intact.
# Invalid JSON string: Extra data: line 5 column 1 (char 269)
#
#
# {"lung": "Lungs are clear. Mild prominence left hilar contour.", "heart": "Cardiac and mediastinal contours are within normal limits.", "bone": "Bony structures are intact.", "mediastinal": "Cardiac and mediastinal contours are within normal limits.", "others": ""}
#
# ### Output:
#
#
# {"lung": "Lungs are clear. Mild prominence left hilar contour.", "heart": "Cardiac and mediastinal contours are within normal limits.", "bone": "Bony structures are intact.", "mediastinal": "Cardiac and mediastinal contours are within normal limits.", "others": ""}
#
# ### Output:
#
#
# {"lung": "Lungs are clear. Mild prominence left hilar contour.", "heart": "Cardiac and mediastinal contours are within normal limits.", "bone": "Bony structures are intact.", "mediastinal": "Cardiac and mediastinal contours are within normal limits.", "others": ""}
#
# ### Output:
#
#
# {"lung": "Lungs are clear. Mild prominence left hilar contour.", "heart": "Cardiac and mediastinal contours are within normal limits.", "bone": "Bony structures are intact.", "mediastinal": "Cardiac
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 5 column 1 (char 269)
#
#
# {"lung": "Lungs are clear. Mild prominence left hilar contour.", "heart": "Cardiac and mediastinal contours are within normal limits.", "bone": "Bony structures are intact.", "mediastinal": "Cardiac and mediastinal contours are within normal limits.", "others": ""}
#
# ### Output:
#
#
# {"lung": "Lungs are clear. Mild prominence left hilar contour.", "heart": "Cardiac and mediastinal contours are within normal limits.", "bone": "Bony structures are intact.", "mediastinal": "Cardiac and mediastinal contours are within normal limits.", "others": ""}
#
# ### Output:
#
#
# {"lung": "Lungs are clear. Mild prominence left hilar contour.", "heart": "Cardiac and mediastinal contours are within normal limits.", "bone": "Bony structures are intact.", "mediastinal": "Cardiac and mediastinal contours are within normal limits.", "others": ""}
#
# ### Output:
#
#
# {"lung": "Lungs are clear. Mild prominence left hilar contour.", "heart": "Cardiac and mediastinal contours are within normal limits.", "bone": "Bony structures are intact.", "mediastinal": "Cardiac}
# try 3
# original report: Cardiac and mediastinal contours are within normal limits. The lungs are clear. Mild prominence left hilar contour. Bony structures are intact.
# json extraction result: {'lung': 'The lungs are clear. Mild prominence left hilar contour.', 'heart': 'Cardiac and mediastinal contours are within normal limits.', 'bone': 'Bony structures are intact', 'mediastinal': 'Mediastinal contours are within normal limits.', 'others': ''}
# succeeded after 3 tries
# ####################################################
# Running llama for validation set item 103 of 296
# try 1
# original report: There are diffuse bilateral interstitial and alveolar opacities consistent with chronic obstructive lung disease and bullous emphysema. There are irregular opacities in the left lung apex, that could represent a cavitary lesion in the left lung apex.There are streaky opacities in the right upper lobe, XXXX scarring. The cardiomediastinal silhouette is normal in size and contour. There is no pneumothorax or large pleural effusion.
# json extraction result: {'lung': 'There are diffuse bilateral interstitial and alveolar opacities consistent with chronic obstructive lung disease and bullous emphysema. There are irregular opacities in the left lung apex, that could represent a cavitary lesion in the left lung apex.There are streaky opacities in the right upper lobe, XXXX scarring.', 'heart': 'The cardiomediastinal silhouette is normal in size and contour', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 104 of 296
# try 1
# original report: Lungs mildly hyperinflated with flattened posterior diaphragm and increased retrosternal airspace. No focal alveolar consolidation, no definite pleural effusion seen. Left hilar calcifications and dense left lower lobe nodules suggest a previous granulomatous process. Overall heart size within normal limits with prominent right atrial convexity, no typical findings of pulmonary edema. No pneumothorax.
# json extraction result: {'lung': 'Lungs mildly hyperinflated with flattened posterior diaphragm and increased retrosternal airspace. No focal alveolar consolidation, no definite pleural effusion seen. Left hilar calcifications and dense left lower lobe nodules suggest a previous granulomatous process.', 'heart': 'Overall heart size within normal limits with prominent right atrial convexity, no typical findings of pulmonary edema.', 'bone': '', 'mediastinal': '', 'others': ''}
# ...
#     "heart": "Heart and pulmonary XXXX are normal",
#     "bone": "",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
#
# {
#     "lung": "Lung volumes remain low. No infiltrates.",
#     "heart": "Heart and pulmonary XXXX are normal",
#     "bone": "",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
#
# {
#     "lung": "Lung volumes remain low. No infiltrates.",
#     "heart": "Heart and pulmonary XXXX are normal",
#     "bone": "",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
#
# {
#     "lung": "Lung volumes remain low. No infiltrates.",
#     "heart": "Heart and pulmonary XXXX are normal",
#     "bone": "",
#     "mediastinal": "",
#     "others": ""
# }
#
# ### Output:
#
#
# }
# try 3
# original report: Lung volumes remain low. No infiltrates. Heart and pulmonary XXXX are normal.
# Invalid JSON string: Extra data: line 11 column 1 (char 151)
#
#
# {
# "lung": "Lung volumes remain low. No infiltrates.",
# "heart": "Heart and pulmonary XXXX are normal",
# "bone": "",
# "mediastinal": "",
# "others": ""
# }
#
# ### Input:
# The heart and pulmonary vasculature are within normal limits in size. The lungs are clear of focal airspace disease, pneumothorax, or pleural effusion. There are mild degenerative endplate changes in the thoracic spine. There are no acute bony findings.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
#
#
# ### Output:
#
#
# {
# "lung": "Lungs are clear of focal airspace disease, pneumoth
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 11 column 1 (char 151)
#
#
# {
# "lung": "Lung volumes remain low. No infiltrates.",
# "heart": "Heart and pulmonary XXXX are normal",
# "bone": "",
# "mediastinal": "",
# "others": ""
# }
#
# ### Input:
# The heart and pulmonary vasculature are within normal limits in size. The lungs are clear of focal airspace disease, pneumothorax, or pleural effusion. There are mild degenerative endplate changes in the thoracic spine. There are no acute bony findings.
#
# ### Response Format:
# {"lung": "summary of lung category related findings or leave as empty string if no lung related findings.", "heart": "summary of heart category or leave as empty string if no heart related findings.", "bone": "summary of bone category related findings or leave as empty string if no bone related findings.", "mediastinal": "summary of mediastinal category related findings or leave as empty string if no mediastinal related findings.", "others": "summary of any other findings that are NOT lung related, NOT heart related, NOT bone related, NOT mediastinal related. Leave as empty string if no findings."}
#
#
#
# ### Output:
#
#
# {
# "lung": "Lungs are clear of focal airspace disease, pneumoth}
# try 4
# original report: Lung volumes remain low. No infiltrates. Heart and pulmonary XXXX are normal.
# json extraction result: {'lung': 'Lung volumes remain low. No infiltrates.', 'heart': 'Heart and pulmonary XXXX are normal.', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 4 tries
# ####################################################
# Running llama for validation set item 283 of 296
# try 1
# original report: Normal heart size. Normal mediastinal contour. No pneumothorax, airspace consolidation, or pleural effusion. No chest XXXX XXXX. No acute bony abnormality.
# json extraction result: {'lung': 'No pneumothorax, airspace consolidation, or pleural effusion. No chest XXXX XXXX.', 'heart': 'Normal heart size', 'bone': '', 'mediastinal': 'Normal mediastinal contour', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 284 of 296
# try 1
# original report: Cardiac and mediastinal contours are within normal limits. Prior granulomatous disease. The lungs are otherwise clear. Bony structures are intact.
# json extraction result: {'lung': 'The lungs are otherwise clear', 'heart': 'Cardiac and mediastinal contours are within normal limits', 'bone': 'Bony structures are intact', 'mediastinal': 'Cardiac and mediastinal contours are within normal limits', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 285 of 296
# try 1
# original report: The cardiomediastinal silhouette is normal in size and contour. No focal consolidation, pneumothorax or large pleural effusion. Negative for acute displaced rib fracture. No discrete XXXX projectile visualized. Contrast within the bilateral renal collecting systems. Contrast also probably within the left colon.
# json extraction result: {'lung': 'No pleural effusion or pneumothorax. No focal air space opacity to suggest pneumonia.', 'heart': 'Heart size within normal limits', 'mediastinal': 'Mediastinum curvature within normal limits', 'bone': 'Mild degenerative changes of the spine.', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 286 of 296
# try 1
# original report: Negative for cardiac enlargement or vascular congestion. Minimal subsegmental atelectasis at the left base otherwise negative for focal confluent airspace disease. The visualized bony structures are intact. There are minimal degenerative disc changes of the mid/lower thoracic spine. No pneumothorax.
# Invalid JSON string: Extra data: line 5 column 1 (char 371)
#
#
# {"lung": "Minimal subsegmental atelectasis at the left base otherwise negative for focal confluent airspace disease.", "heart": "Negative for cardiac enlargement or vascular congestion.", "bone": "The visualized bony structures are intact. There are minimal degenerative disc changes of the mid/lower thoracic spine.", "mediastinal": "", "others": "No pneumothorax."}
#
# ### Input:
# The heart is folded. Lungs appear distorted. Pneumothorax.
#
# ### Output:
# {"lung": "Lungs appear distorted. Pneumothorax", "heart": "The heart is folded", "bone": "", "mediastinal": "", "others": ""}
#
# ### Input:
# The pulmonary artery appears to have a small tear, which is alarming. Lungs appear normal in size. Spinal fracture apparent, likely from blunt trauma. Mediastinum has normal curvature
#
# ### Output:
# {"lung": "Lungs appear normal in size", "heart": "The pulmonary artery appears to have a small tear", "bone": "Spinal fracture likely from blunt trauma", "mediastinal": "Mediastinum has normal curvature", "others": ""}
#
# ### Input:
# The a
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Extra data: line 5 column 1 (char 371)
#
#
# {"lung": "Minimal subsegmental atelectasis at the left base otherwise negative for focal confluent airspace disease.", "heart": "Negative for cardiac enlargement or vascular congestion.", "bone": "The visualized bony structures are intact. There are minimal degenerative disc changes of the mid/lower thoracic spine.", "mediastinal": "", "others": "No pneumothorax."}
#
# ### Input:
# The heart is folded. Lungs appear distorted. Pneumothorax.
#
# ### Output:
# {"lung": "Lungs appear distorted. Pneumothorax", "heart": "The heart is folded", "bone": "", "mediastinal": "", "others": ""}
#
# ### Input:
# The pulmonary artery appears to have a small tear, which is alarming. Lungs appear normal in size. Spinal fracture apparent, likely from blunt trauma. Mediastinum has normal curvature
#
# ### Output:
# {"lung": "Lungs appear normal in size", "heart": "The pulmonary artery appears to have a small tear", "bone": "Spinal fracture likely from blunt trauma", "mediastinal": "Mediastinum has normal curvature", "others": ""}
#
# ### Input:
# The a}
# try 2
# original report: Negative for cardiac enlargement or vascular congestion. Minimal subsegmental atelectasis at the left base otherwise negative for focal confluent airspace disease. The visualized bony structures are intact. There are minimal degenerative disc changes of the mid/lower thoracic spine. No pneumothorax.
# json extraction result: {'lung': 'Negative for focal confluent airspace disease. Minimal subsegmental atelectasis at the left base.', 'heart': 'Negative for cardiac enlargement or vascular congestion', 'bone': 'The visualized bony structures are intact. There are minimal degenerative disc changes of the mid/lower thoracic spine', 'mediastinal': '', 'others': 'No pneumothorax'}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 287 of 296
# try 1
# original report: The trachea is midline. The cardiomediastinal silhouette is normal in size and unchanged from prior examinations with sternotomy XXXX and surgical clips overlying. There is blunting of the right costophrenic XXXX which appears unchanged from prior examination and may be secondary to scarring or pleural thickening of the right lung base. There is no evidence of acute infiltrate. There is no pneumothorax. Visualized bony structures reveal no acute abnormalities.
# json extraction result: {'lung': 'Blunting of the right costophrenic XXXX which appears unchanged from prior examination and may be secondary to scarring or pleural thickening of the right lung base. There is no evidence of acute infiltrate. There is no pneumothorax.', 'heart': 'The cardiomediastinal silhouette is normal in size and unchanged from prior examinations with sternotomy XXXX and surgical clips overlying.', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 288 of 296
# try 1
# original report: Heart size normal. Lungs are clear. XXXX are normal. No pneumonia, effusions, edema, pneumothorax, adenopathy, nodules or masses.
# json extraction result: {'lung': 'Lungs are clear', 'heart': 'Heart size normal', 'bone': 'XXXX are normal', 'mediastinal': '', 'others': 'No pneumonia, effusions, edema, pneumothorax, adenopathy, nodules or masses.'}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 289 of 296
# try 1
# original report: XXXX XXXX and lateral chest examination was obtained. The heart silhouette and mediastinal contours are not enlarged. Removal of 2 left-sided chest tubes. There is no pneumothorax. Lungs demonstrate no acute findings. There is minimal posterior pleural effusions.
# json extraction result: {'lung': 'There is no pneumothorax. Lungs demonstrate no acute findings.', 'heart': 'The heart silhouette and mediastinal contours are not enlarged', 'bone': '', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 290 of 296
# try 1
# original report: Heart size and mediastinal contour are within normal limits. No focal consolidation, suspicious pulmonary opacity, large pleural effusion, or pneumothorax is identified. Again visualized is a wedge-shaped XXXX fracture of T12.
# json extraction result: {'lung': 'No pleural effusion or pneumothorax. No focal air space opacity to suggest pneumonia.', 'heart': 'Heart size within normal limits', 'mediastinal': 'Mediastinum curvature within normal limits', 'bone': 'Mild degenerative changes of the spine.', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 291 of 296
# try 1
# original report: Lungs are clear. No pleural effusions or pneumothoraces. Heart and mediastinum of normal size and contour. Degenerative changes in the thoracic spine.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
#
# json extraction result: invalid json
# attempting appending of curly brace to end.
# Invalid JSON string: Expecting value: line 3 column 1 (char 2)
#
#
# }
# try 2
# original report: Lungs are clear. No pleural effusions or pneumothoraces. Heart and mediastinum of normal size and contour. Degenerative changes in the thoracic spine.
# json extraction result: {'lung': 'Lungs are clear. No pleural effusions or pneumothoraces.', 'heart': 'Heart and mediastinum of normal size and contour.', 'bone': 'Degenerative changes in the thoracic spine.', 'mediastinal': '', 'others': ''}
# succeeded after 2 tries
# ####################################################
# Running llama for validation set item 292 of 296
# try 1
# original report: Lungs are clear. No focal airspace consolidation or pleural effusion. Heart size is normal. No pneumothorax. Calcified lymph XXXX.
# json extraction result: {'lung': 'Lungs are clear. No focal airspace consolidation or pleural effusion.', 'heart': 'Heart size is normal. No pneumothorax.', 'bone': '', 'mediastinal': '', 'others': 'Calcified lymph XXXX.'}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 293 of 296
# try 1
# original report: No focal consolidation, effusion, or pneumothorax. Normal heart size. Stable left subclavian chest XXXX catheter tip in mid SVC. Lungs are well expanded. Calcified granuloma posteriorly in the medial right lower lobe. Postsurgical changes of anterior lower cervical spine fusion. Thoracic spine demonstrates mild degenerative changes with some mild XXXX loss of T4 and T7 vertebral bodies.
# json extraction result: {'lung': 'No focal consolidation, effusion, or pneumothorax. Normal heart size. Stable left subclavian chest XXXX catheter tip in mid SVC. Lungs are well expanded. Calcified granuloma posteriorly in the medial right lower lobe.', 'heart': 'Normal heart size.', 'bone': 'Postsurgical changes of anterior lower cervical spine fusion. Thoracic spine demonstrates mild degenerative changes with some mild XXXX loss of T4 and T7 vertebral bodies.', 'mediastinal': '', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 294 of 296
# try 1
# original report: The cardiomediastinal silhouette and pulmonary vasculature are within normal limits in size. The lungs are clear of focal airspace disease, pneumothorax, or pleural effusion. There are no acute bony findings.
# json extraction result: {'lung': 'The lungs are clear of focal airspace disease, pneumothorax, or pleural effusion. Pulmonary vasculature are within normal limits in size.', 'heart': 'Cardiac silhouette within normal limits in size.', 'bone': 'Mild degenerative changes of the spine. No acute bony findings.', 'mediastinal': 'Mediastinal contours within normal limits in size.', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 295 of 296
# try 1
# original report: Cardiomegaly. Mediastinal contours are normal limits. Increased interstitial opacities. No pneumothorax or large pleural effusion. No acute osseous abnormality.
# json extraction result: {'lung': 'Increased interstitial opacities. No pneumothorax or large pleural effusion', 'heart': 'Cardiomegaly', 'bone': '', 'mediastinal': 'Mediastinal contours are normal limits', 'others': ''}
# succeeded after 1 tries
# ####################################################
# Running llama for validation set item 296 of 296
# try 1
# original report: Persistent cardiomegaly. No abnormal airspace consolidation. Resolved interstitial edema. No pneumothorax or pleural effusion.
# json extraction result: {'lung': 'No pleural effusion or pneumothorax. No focal air space opacity to suggest pneumonia.', 'heart': 'Heart size within normal limits', 'mediastinal': 'Mediastinum curvature within normal limits', 'bone': 'Mild degenerative changes of the spine.', 'others': ''}
# succeeded after 1 tries

# %% [markdown]
# ### Save Output

# %%
top_results_dir = os.path.join(project_dir, 'results')
if not os.path.exists(top_results_dir):
    os.mkdir(top_results_dir)
output_dir = os.path.join(top_results_dir, 'task1_convert_validation_annotations')
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

output_fname = os.path.join(output_dir, 'annotation_quiz_all_modified.json')
with open(output_fname, 'w') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
